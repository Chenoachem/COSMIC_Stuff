# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import viewer
import numpy as np

# %%
DATA_DIR = '/Users/chenoatremblay/Documents/COSMIC-VLA/MeerKAT_Test'

# %%
viewer.scan_dir(DATA_DIR)
# Out:
# stamp 0 from /Users/chenoatremblay/Documents/COSMIC-VLA/MeerKAT_Test/guppi_59863_59864_005553_J1939-6342_0001.stamps
# stamp 1 from /Users/chenoatremblay/Documents/COSMIC-VLA/MeerKAT_Test/guppi_59863_59864_005553_J1939-6342_0001.stamps
# stamp 2 from /Users/chenoatremblay/Documents/COSMIC-VLA/MeerKAT_Test/guppi_59863_59864_005553_J1939-6342_0001.stamps
# 3 stamps shown total

# %%
f = viewer.find_stamp_files(DATA_DIR)

# %%
list(f)
# Out:
# ['/Users/chenoatremblay/Documents/COSMIC-VLA/MeerKAT_Test/guppi_59863_59864_005553_J1939-6342_0001.stamps']

# %%
stp=viewer.read_stamps("/Users/chenoatremblay/Documents/COSMIC-VLA/MeerKAT_Test/guppi_59863_59864_005553_J1939-6342_0001.stamps.1")

# %%
list(stp)

# %%
dir(stp)
# Out:
# ['__class__',
#  '__del__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'close',
#  'gi_code',
#  'gi_frame',
#  'gi_running',
#  'gi_yieldfrom',
#  'send',
#  'throw']

# %%
filename="/Users/chenoatremblay/Documents/COSMIC-VLA/MeerKAT_Test/guppi_59863_59864_005553_J1939-6342_0001.stamps.1"
stamps = list(viewer.read_stamps(filename))

# %%
stamps.__class__
# Out:
# list

# %%
print(stamps)
# Out:
# [<viewer.Stamp object at 0x12daf3310>, <viewer.Stamp object at 0x12d82b700>, <viewer.Stamp object at 0x12daed8e0>]

# %%
dir(stamps[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_real_array',
#  'complex_array',
#  'real_array',
#  'show_antenna',
#  'show_antennas',
#  'show_incoherent',
#  'stamp']

# %%
stamps[0].show_antennas()

# %%
stamps[0].show_incoherent()

# %%
dir(stamps[0].stamp)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '_get',
#  '_get_by_field',
#  '_has',
#  '_has_by_field',
#  '_parent',
#  '_which',
#  '_which_str',
#  'as_builder',
#  'coarseChannel',
#  'data',
#  'dec',
#  'fch1',
#  'fftSize',
#  'foff',
#  'is_root',
#  'numAntennas',
#  'numChannels',
#  'numPolarities',
#  'numTimesteps',
#  'ra',
#  'schema',
#  'seticoreVersion',
#  'sourceName',
#  'startChannel',
#  'telescopeId',
#  'to_dict',
#  'total_size',
#  'tsamp',
#  'tstart',
#  'which']

# %%
stamps[0].stamp.startChannel
# Out:
# 84522

# %%
stamps[0].stamp.sourceName
# Out:
# 'J1939-6342'

# %%
stamps[0].stamp.ra
# Out:
# 19.656952777777775

# %%
stamps[0].stamp.fch1
# Out:
# 886.9599592387676

# %%
stamps[0].stamp.schema
# Out:
# <schema for stamp_capnp:Stamp>
